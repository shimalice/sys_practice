# %% [markdown]
# <br />
#
# <div style="text-align: center;">
# <font size="7">Pythonによるデータ解析</font>
# </div>
# <br />
# <div style="text-align: right;">
# <font size="4">学籍番号:201511511 氏名:宍倉　基文</font>
# </div>
#
# <br />

# %%
print("Hello, jupyter!")
# Out:
# Hello, jupyter!

# %%
f = open('data.txt', 'r')
for line in f:
    print(line)
f.close()
# Out:
# jupyter notebook test

# %%
f = open('message.txt', 'w')
f.write('hello!')
f.close()

# %% [markdown]
# ## リストとタプル

# %%
"""リスト """
animals = ['dog', 'cat', 'mouse', 'gorilla']
"""タプル """
summer = ('sun', 'beach', 'wave', 'sea', 'sky')
animals[0]
# Out:
# 'dog'

# %%
"""リストとタプルのタプル"""
combined = [animals, summer]
combined
# Out:
# [['dog', 'cat', 'mouse', 'gorilla'], ('sun', 'beach', 'wave', 'sea', 'sky')]

# %%
"""スライス"""
summer[1:3]
# Out:
# ('beach', 'wave')

# %%
"""インデックスを求める"""
animals.index('mouse')
# Out:
# 2

# %% [markdown]
# - リストは値を後から書き換えられるが、タプルは値を書き換えることができない。
# - タプルはリストより消費スペースが少ない。
# - 関数の引数はタプルとして渡される。

# %% [markdown]
# ## CSVファイルの読み込み

# %%
f = open('iris.data', 'r')
for line in f:
    elems = line.split(',')
    if len(elems) > 1:
        print(elems[4])
f.close()
# Out:
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-setosa
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# Iris-versicolor
#
# ...

# %%
f = open('iris.data', 'r')
totalPetalLength = 0
sampleNum = 0
for line in f:
    elems = line.split(',')
    if len(elems) > 1:
        totalPetalLength += float(elems[2])
        sampleNum += 1
        print('average petal length is ', "{:.4f}".format(totalPetalLength / sampleNum))
f.close()
# Out:
# average petal length is  1.4000
# average petal length is  1.4000
# average petal length is  1.3667
# average petal length is  1.4000
# average petal length is  1.4000
# average petal length is  1.4500
# average petal length is  1.4429
# average petal length is  1.4500
# average petal length is  1.4444
# average petal length is  1.4500
# average petal length is  1.4545
# average petal length is  1.4667
# average petal length is  1.4615
# average petal length is  1.4357
# average petal length is  1.4200
# average petal length is  1.4250
# average petal length is  1.4176
# average petal length is  1.4167
# average petal length is  1.4316
# average petal length is  1.4350
# average petal length is  1.4476
# average petal length is  1.4500
# average petal length is  1.4304
# average petal length is  1.4417
# average petal length is  1.4600
# average petal length is  1.4654
# average petal length is  1.4704
# average petal length is  1.4714
# average petal length is  1.4690
# ...

# %% [markdown]
# ## 辞書

# %%
capitals = {
    'UK' : 'London',
    'France' : 'Paris',
    'Germany' : 'Berlin'
}
print(capitals['France'])
# Out:
# Paris

# %%
"""追加"""
capitals['Italy'] = 'Rome'
"""削除"""
del capitals['UK']

# %% [markdown]
# ## 関数

# %%
def factorial(n):
    f = 1
    for i in range(1,n+1):
        f = f * i
    return f
factorial(100)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
def sum(n):
    f = 0
    for i in range(1,n+1):
        f += i
    return f
sum(4)
# Out:
# 10

# %% [markdown]
# ### Matplotlib

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = 0.3 * np.ones(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## scikit-learn

# %%
ls
# Out:
# data.txt                  message.txt               python_data_analysis.pdf
# iris.data                 pyml/                     python_test.ipynb

# %%
ls pyml
# Out:
# README.md                       mnist_cnn_predict_simple.py
# __init__.py                     mnist_cnn_train.py
# abalone.data                    mnist_cnn_train_and_test.py
# binSimpPercep.py                multiLayerPercep.py
# cifar10_cnn_copied.py           polyAbalone.py
# cifar10_cnn_load_data.py        prog1.py
# cifar10_cnn_train.py            resize_images.py
# clusIris.py                     run_face_train_and_predict.py
# cnn_predict.py                  see_mnist.py
# cnn_train.py                    setup.sh*
# data_utils.py                   show_cifar10.py
# generic_utils.py                show_layers.py
# gpAirQuality.py                 show_mnist.py
# image_to_array.py               show_mnist_amazon_aws.py
# linAbalone.py                   show_mnist_deeplearning_net.py
# mnist.py                        show_mnist_image.py
# mnist_cnn_predict.py            showimage.py

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# #### 独立変数と従属変数の値が共に知られている多数の標本（訓練データ）をもとに、独立変数から従属変数の値を求める（予測する）関数を学習するタスクを回帰と呼ぶ。線形回帰は回帰に対するもっともシンプルな方法のひとつであり、学習される関数が一次関数となるものである。一次関数であるため、データから求められる（学習される）のは各独立変数に対する重みと定数項（バイアス項）である。

# %% [markdown]
# ```python
# #!/usr/bin/env python
# # linear regression to abalone data
#
# from sklearn import linear_model
# import matplotlib.pyplot as plt
# import numpy as np
#
# # read data
# datalist = []
# f = open('pyml/abalone.data', 'r')
# for line in f:
#     line = line.rstrip()
#     elems = line.split(',')
#     datalist.append(elems[1:])
# f.close()
# data = np.array(datalist)
# # length
# x = np.c_[np.float_(data[:,0])]
# # rings
# y = np.c_[np.float_(data[:,-1])]
#
# lr = linear_model.LinearRegression()
# lr.fit(x, y)
#
# # mesh for x_test
# x_test = np.linspace(x.min(), x.max(), 1000)
#
# #coef_: 傾き, intercept_: 切片
# predicted = lr.coef_[0] * x_test + lr.intercept_ * np.ones(x_test.shape)
#
# fig, ax = plt.subplots()
# ax.scatter(x, y, c='red', marker='o', label='observed', lw=0)
# ax.scatter(x_test, predicted, c='blue', marker='o', label='predicted', lw=0)
#
# ax.tick_params(axis='both', which='major', labelsize=18)
# ax.tick_params(axis='both', which='minor', labelsize=18)
# ax.legend(loc='upper left', fontsize=18)
# ax.set_xlabel('length', fontsize=18)
# ax.set_ylabel('rings', fontsize=18)
#
# plt.show()
# ```

# %% [markdown]
# #### 上記のプログラムにおいて、lr.fit(x, y)が実際に線形回帰を行っている箇所であり、それによって得られた係数がlr.coef_に、定数項（回帰直線のy 切片）がlr.intercept_に格納される。回帰直線を描くため、np.linspace(x.min(), x.max(), 1000)によってx の最小値から最大値までを1000 区間に等分割して得られる数列x_test を作っている。これとlr.coef_とlr.intercept_によって（x_test のそれぞれの値に対する）予測値を並べたベクトルpredicted を作成している。ax.scatter によって散布図（scatter plot）を描くことで無数の点が直線上に並び、回帰直線として見ることができる。

# %%
run pyml/linAbalone.py

# %%
# %matplotlib inline
plt.scatter(x_test, predicted, c='blue', marker='o', label='predicted', lw=0)

# %%
x_train = x[0:800]
y_train = y[0:800]
x_test = x[800:1000]
y_test = y[800:1000]

# %%
lr = linear_model.LinearRegression()
lr.fit(x_train, y_train)

# %%
x_test_mat = x_test.reshape((x_test.shape[0], 1)) # 1000次元のベクトルから1000,1の行列

# %%
lr.predict(x_test_mat)
# Out:
# array([[  3.22286404],
#        [  3.23393546],
#        [  3.24500687],
#        [  3.25607829],
#        [  3.26714971],
#        [  3.27822112],
#        [  3.28929254],
#        [  3.30036395],
#        [  3.31143537],
#        [  3.32250678],
#        [  3.3335782 ],
#        [  3.34464961],
#        [  3.35572103],
#        [  3.36679244],
#        [  3.37786386],
#        [  3.38893528],
#        [  3.40000669],
#        [  3.41107811],
#        [  3.42214952],
#        [  3.43322094],
#        [  3.44429235],
#        [  3.45536377],
#        [  3.46643518],
#        [  3.4775066 ],
#        [  3.48857802],
#        [  3.49964943],
#        [  3.51072085],
#        [  3.52179226],
#        [  3.53286368],
#        [  3.54393509],
#        [  3.55500651],
#        [  3.56607792],
#        [  3.57714934],
#        [  3.58822075],
#        [  3.59929217],
#        [  3.61036359],
#        [  3.621435  ],
#        [  3.63250642],
#        [  3.64357783],
#        [  3.65464925],
# ...

# %%
#!/usr/bin/env python
# linear regression to abalone data

from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# read data
datalist = []
f = open('pyml/abalone.data', 'r')
for line in f:
    line = line.rstrip()
    elems = line.split(',')
    datalist.append(elems[1:])
f.close()
data = np.array(datalist)
# length
x = np.c_[np.float_(data[:,0])]
# rings
y = np.c_[np.float_(data[:,-1])]

x_train = x[0:800]
y_train = y[0:800]
x_test = x[800:1000]
y_test = y[800:1000]

lr = linear_model.LinearRegression()
lr.fit(x_train, y_train)

x_test_mat = x_test.reshape((x_test.shape[0], 1))
predicted = lr.predict(x_test_mat)
# mesh for x_test
#x_test = np.linspace(x.min(), x.max(), 1000)

#coef_: 傾き, intercept_: 切片
#predicted = lr.coef_[0] * x_test + lr.intercept_ * np.ones(x_test.shape)

fig, ax = plt.subplots()
ax.scatter(x, y, c='red', marker='o', label='observed', lw=0)
ax.scatter(x_test, predicted, c='blue', marker='o', label='predicted', lw=0)

ax.tick_params(axis='both', which='major', labelsize=18)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.legend(loc='upper left', fontsize=18)
ax.set_xlabel('length', fontsize=18)
ax.set_ylabel('rings', fontsize=18)

plt.show()

# %%
lr.score(x_test, y_test)
# Out:
# -1.6274633116078907

# %%
cat pyml/linreg_happiness.py
# Out:
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# from sklearn import linear_model
# d = pd.read_csv('pyml/world-happiness-report/2017.csv')
# happiness = d['Happiness.Score']
# gdp = d['Economy..GDP.per.Capita.']
# japanID = 50
# jhappiness = d.ix[japanID,'Happiness.Score']
# jgdp = d.ix[japanID, 'Economy..GDP.per.Capita.']
# lr = linear_model.LinearRegression()
# lr.fit(gdp.values.reshape((-1,1)), happiness.values)
# gdp_test = np.linspace(gdp.min(), gdp.max(), 10000)
# happiness_predict = lr.predict(gdp_test.reshape((-1,1)))
# fig, ax = plt.subplots()
# ax.scatter(gdp, happiness, label='All', marker='*')
# ax.scatter(jgdp, jhappiness, c='red', label='Japan', s=50)
# ax.scatter(gdp_test, happiness_predict, c='green', marker='.' , label='pred')
# ax.legend(loc='lower left')
# ax.set_xlabel('Economy..GDP.per.Capita.')
# ax.set_ylabel('Happiness.Score')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import linear_model
d = pd.read_csv('pyml/world-happiness-report/2017.csv')
happiness = d['Happiness.Score']
gdp = d['Economy..GDP.per.Capita.']
japanID = 50
jhappiness = d.ix[japanID,'Happiness.Score']
jgdp = d.ix[japanID, 'Economy..GDP.per.Capita.']
lr = linear_model.LinearRegression()
lr.fit(gdp.values.reshape((-1,1)), happiness.values)
gdp_test = np.linspace(gdp.min(), gdp.max(), 10000)
happiness_predict = lr.predict(gdp_test.reshape((-1,1)))
fig, ax = plt.subplots()
ax.scatter(gdp, happiness, label='All', marker='*')
ax.scatter(jgdp, jhappiness, c='red', label='Japan', s=50)
ax.scatter(gdp_test, happiness_predict, c='green', marker='.' , label='pred')
ax.legend(loc='lower left')
ax.set_xlabel('Economy..GDP.per.Capita.')
ax.set_ylabel('Happiness.Score')
# Out:
# /Users/motofumishishikura/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/ipykernel/__main__.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# ### Polynomial Regression

# %% [markdown]
# #### 以下のサンプルコードpolyAbalone.py ではabalone データのうち、length（長さ）から全体重量（whole weight）を予測する二次の多項式回帰を行う。

# %%
cat pyml/polyAbalone.py
# Out:
# #!/usr/bin/env python
# # polynomial regression to abalone data
#
# from sklearn import linear_model
# import matplotlib.pyplot as plt
# import numpy as np
#
# datalist = []
# f = open('pyml/abalone.data', 'r')
# for line in f:
#     line = line.rstrip()
#     elems = line.split(',')
#     datalist.append(elems[1:])
# f.close()
# data = np.array(datalist)
# x = np.c_[np.float_(data[:,0])]
# y = np.c_[np.float_(data[:,4])]
#
# lr = linear_model.LinearRegression()
#
# X = np.hstack((x, np.power(x,2)))
#
# lr.fit(X, y)
#
# x_test = np.linspace(x.min(), x.max(), 1000)
#
# predicted = lr.coef_[0,1] * np.power(x_test,2) + lr.coef_[0,0] * x_test + lr.intercept_ * np.ones(x_test.shape)
#
# fig, ax = plt.subplots()
# ax.scatter(x, y, c='red', marker='o', label='observed', lw=0)
# ax.scatter(x_test, predicted, c='blue', marker='o', label='predicted', lw=0)
#
# ax.tick_params(axis='both', which='major', labelsize=18)
# ax.tick_params(axis='both', which='minor', labelsize=18)
# ...

# %% [markdown]
# #### 上記のプログラムでは二次の多項式回帰を行うため、length とそれを二乗したものを新たな独立変数としている。これをX = np.hstack((x, np.power(x,2)))によって求めている。訓練の結果として2 次の項の係数がlr.coef_[0,1]に、1 次の項の係数がlr.coef_[0,0]に、定数項がlr.intercept_に入るので、これらとベクトルx_test の値から予測値ベクトルpredicted を求めている。視覚化すると二次関数（放物線）によってフィッティングしているのが分かる。

# %%
run pyml/polyAbalone.py

# %% [markdown]
# ### Gaussian Process Regression

# %% [markdown]
# #### ガウシアンプロセス回帰（GP 回帰）はカーネル法のひとつであり、独立変数の値がテストデータに近い訓練データの従属変数の値を使って予測を行うというものである。GP 回帰を使うと訓練データ周辺を通って結んでいく曲線が得られる。

# %%
cat pyml/gpAirQuality.py
# Out:
# #!/usr/bin/env python
# # Gaussian process regression to Air Quality Data in UCI-MLR
#
# import matplotlib.pyplot as plt
# import numpy as np
# from sklearn.gaussian_process import GaussianProcessRegressor
# from sklearn.gaussian_process.kernels import ConstantKernel, RBF
#
# # data read and visualization parameters
# offsetTimePoint = 100
# maxTimePoint = 96
# subsamplingSkip = 6
# testTimePointSamplingNum = 1000
#
# # read data
# datalist = []
# f = open('AirQualityUCI.csv', 'r')
# for line in f:
#     line = line.rstrip()
#     line = line.replace(",",".")
#     elems = line.split(';')
#     if len(elems[0]) > 1:
#         datalist.append(elems)
# f.close()
# attr_and_data = np.array(datalist)
# data = attr_and_data[offsetTimePoint:offsetTimePoint+maxTimePoint:subsamplingSkip,:]
# dataMin = 0
# dataMax = maxTimePoint
# x_train = np.c_[np.linspace(dataMin, dataMax, data.shape[0])]
# y_train = np.c_[np.float_(data[:,12])]  # get temperature
# ...

# %% [markdown]
# #### 上記コードのax.fill では95%信頼区間を緑色に塗りつぶしている。fill では点の列を与えることでその内側が塗りつぶされる。[x_test, x_test[::-1]によってx 座標の値がx_testの最初の要素から順に辿っていき、最後の要素まで行った後、また最初の要素まで（[::-1]によって-1 ずつ動くので）戻っていく。y 座標に関しても同様に最初の要素から最後の要素まで行き、また戻ってくる。GP 回帰では独立変数の各値について従属変数の値がガウス分布に従うとモデル化される。回帰の結果、独立変数の各値について従属変数の期待値y_pred と分散sigmaが求まる。y_pred に±1.96 * sigma を足すことで95%信頼区間が描ける。ax.plot では予測値y_pred が青で、ax.scatter では訓練データy_train が赤で描かれている。

# %%
run pyml/gpAirQuality.py

# %% [markdown]
# ### Clustering

# %% [markdown]
# #### クラスタリングとは観測されたデータに対し、自然な分け方を見つけるタスクである。分類や回帰と異なり、クラスタリングでは独立変数と従属変数の区別は存在しない。そのため教師なし学習に分類される。

# %% [markdown]
# ```python
# cat pyml/clusIris.pyimport numpy as np
# import matplotlib.pyplot as plt
#
# from sklearn.cluster import KMeans
# import numpy as np
#
# attrNames = ["sepal length", "sepal width", "petal length", "petal width"]
# targetAttr = [0,2]
#
# datalist = []
# f = open('iris.data', 'r')
# for line in f:
#     line = line.rstrip()
#     elems = line.split(',')
#     if len(elems) > 1:
#       datalist.append(elems[:-1])
# f.close()
#
# X = np.float_(np.array(datalist))
#
# # KMeansクラスの作成, 5クラス
# kres = KMeans(n_clusters=5)
# # クラスタリング
# clus_labels = kres.fit_predict(X)
#
# # 重心
# clusCent = kres.cluster_centers_
#
# fig, ax = plt.subplots()
# ax.scatter(X[:, targetAttr[0]], X[:, targetAttr[1]], c=clus_labels, lw=0)
#
# ax.scatter(clusCent[:, targetAttr[0]], clusCent[:,targetAttr[1]], edgecolors="red", c="red", lw=10)
#
# ax.tick_params(axis='both', which='major', labelsize=18)
# ax.tick_params(axis='both', which='minor', labelsize=18)
# ax.set_xlabel(attrNames[targetAttr[0]], fontsize=18)
# ax.set_ylabel(attrNames[targetAttr[1]], fontsize=18)
#
# plt.show()
# ```

# %% [markdown]
# #### 実際のクラスタリングはclus_labels = kres.fit_predict(X)で行われている。これによってclus_labels は標本数次元のベクトルとなり、その成分は標本がどのクラスタに属しているかを示すラベルである。
# #### 散布図のひとつの点がひとつのサンプルであり、その座標が属性（sepal length とpetalwidth）の値を表している。得られた各クラスタはマーカーの色によって区別している。c=clus_labels と書いていることで各マーカーがclus_labels の成分の値に応じた色で塗られる。
# #### また、各クラスタの重心の座標をclusCent に格納し、赤く大きなマーカーとして描いている。
# #### ここでは属性2 つだけを使って結果を視覚化しているが、クラスタリングにはすべての属性が利用されている。

# %%
run pyml/clusIris.py

# %% [markdown]
# ## 単純パーセプトロン

# %% [markdown]
# #### 単純パーセプトロンはもっとも単純なニューラルネットワークであり、小規模なデータセットに対する分類タスクに利用できる。以下のコードbinSimpPercep.py ではUCI MachineLearning Repository から得られるiris データセット(iris.data)とkeras を用い、アヤメの各部位の大きさからその品種を予測する単純パーセプトロンを訓練し、評価している。プログラムの実行時、同じディレクトリにiris.data を置いておく必要がある。iris データセットには3 つの品種のアヤメから得られたデータであるが、ここでは最初の2 つの品種だけを抜き出し、2 値分類を行っている。

# %%
cat pyml/binSimpPercep.py
# Out:
# import keras
# from keras.models import Sequential
# from keras.layers import Dense, Activation
# import numpy as np
# from sklearn import preprocessing
#
# np.random.seed(2)
#
# attrLabels = ["sepal length", "sepal width", "petal length", "petal width"]
# categoryLabels = ["Iris-setosa", "Iris-versicolor", "Iris-virginica"]
#
# le = preprocessing.LabelEncoder()
# le.fit(categoryLabels);
#
# datalist = []
# depVar = []
# f = open('iris.data', 'r')
# for line in f:
#     line = line.rstrip()
#     elems = line.split(',')
#     if len(elems) > 1:
#         label = elems[-1]
#         if label == categoryLabels[0] or label == categoryLabels[1]:
#             datalist.append(elems[:-1])
#             depVar.append(le.transform([label])[0])
# f.close()
#
# X = np.float_(np.array(datalist))
# y = np.array(depVar)
#
# sampleNum, attrNum = X.shape
#
# model = Sequential()
# model.add(Dense(1, input_shape=(attrNum,)))
# model.add(Activation("sigmoid"))
#
# ...

# %% [markdown]
# #### 上記のプログラムではle = preprocessing.LabelEncoder(), le.fit, le.transformによって文字列ラベル（アヤメの品種）を数値ラベル（0〜1）に変換している。さらにX =np.float_(np.array(datalist))ならびにy = np.array(depVar)において独立変数と従属変数をnumpy の配列に変換している。
# #### model = Sequential()は層を重ねていく形のニューラルネットワークを作ることを決めている。model に密（dense）な中間層と活性化関数（activation function）を重ねることで単純パーセプトロンを実現している。model.compile において最適化手法はsgd（確率勾配降下法）、目的関数はbinary cross-entropy（二値交差エントロピー）、評価基準はaccuracy（精度）を使うように設定している。model.fit において実際の訓練と評価を行っている。
# #### 学習済みのモデルを利用して予測を行うにはたとえば以下のようにする。
# #### model.predict(X[5:6,:])
# #### 引数として与える配列X を5:6 でスライスしているので、5 行目のみが切り出される。そのため上記関数の戻り値はX における5 番目のサンプルがカテゴリ1 に属する確信度を表している。出力にsigmoid 関数を使っているので、戻り値は0 から1 の範囲を取る。これが0.5 未満の場合はカテゴリ0 に属する可能性が高く、0.5 より大きい場合はカテゴリ1 に属する可能性が高いと考えられる。ここでは訓練データX を使っているが、実用上は独立変数の値は分かるが従属変数（正解ラベル）y が分からないデータに対して予測を行うことに意味がある。

# %%
run pyml/binSimpPercep.py
# Out:
# Using TensorFlow backend.
# Epoch 1/10
# 100/100 [==============================] - 0s - loss: 1.5732 - acc: 0.5000
# Epoch 2/10
# 100/100 [==============================] - 0s - loss: 1.3446 - acc: 0.2100
# Epoch 3/10
# 100/100 [==============================] - 0s - loss: 1.2213 - acc: 0.0500
# Epoch 4/10
# 100/100 [==============================] - 0s - loss: 1.1557 - acc: 0.0200
# Epoch 5/10
# 100/100 [==============================] - 0s - loss: 1.1052 - acc: 0.0100
# Epoch 6/10
# 100/100 [==============================] - 0s - loss: 1.0357 - acc: 0.0700
# Epoch 7/10
# 100/100 [==============================] - 0s - loss: 1.0053 - acc: 0.2000
# Epoch 8/10
# 100/100 [==============================] - 0s - loss: 0.9765 - acc: 0.2000
# Epoch 9/10
# 100/100 [==============================] - 0s - loss: 0.9506 - acc: 0.2100
# Epoch 10/10
# 100/100 [==============================] - 0s - loss: 0.9297 - acc: 0.3100

# %% [markdown]
# ## 多層パーセプトロン

# %% [markdown]
# #### 多層パーセプトロンはニューロンの層を重ねることでより複雑な分布を持つデータの分類を可能にしたものである。以下のコードmultiLayerPercep.py では中間層を2 つ重ねているため、多層パーセプトロンになっている。また、前述の単純パーセプトロンの例と異なり、アヤメの3つの品種（3 つのカテゴリ）への分類、すなわち多値分類を行っている。

# %%
cat pyml/multiLayerPercep.py
# Out:
# import keras
# from keras.models import Sequential
# from keras.layers import Dense, Activation
# from keras.utils import np_utils
# import numpy as np
# from sklearn import preprocessing
# np.random.seed(2)
#
# nb_epoch = 100
# nb_internalnodes = 5
#
# attrLabels = ["sepal length", "sepal width", "petal length", "petal width"]
# categoryLabels = ["Iris-setosa", "Iris-versicolor", "Iris-virginica"]
# nb_classes = len(categoryLabels)
#
# le = preprocessing.LabelEncoder()
# le.fit(categoryLabels);
#
# datalist = []
# depVar = []
# f = open('iris.data', 'r')
# for line in f:
#     line = line.rstrip()
#     elems = line.split(',')
#     if len(elems) > 1:
#         label = elems[-1]
#         datalist.append(elems[:-1])
#         depVar.append(le.transform([label])[0])
# f.close()
#
# X = np.float_(np.array(datalist))
# y = np.array(depVar)
# y_oneHot = np_utils.to_categorical(y, nb_classes)
#
# sampleNum, attrNum = X.shape
#
# model = Sequential()
#
# ...

# %% [markdown]
# #### 上記のプログラムではmodel.add(Dense... )という行が2 つあり、Dense（密）な層が2 つ重ねられているため、多層パーセプトロンである。多層パーセプトロンを使う場合、ニューロンを何層重ねるか、また中間層のノード数（上記のプログラムではnb_internalnodes）をいくつに定めると精度が出るかは対象とするタスクやデータの性質によって異なり、工夫が必要となる。試行錯誤によって決められることも多いが、自動で最適化する方法も研究されている。
# #### 層を大量に重ねていったものが深層学習（ディープラーニング）である。
# #### 多値分類のため、最終出力を行う活性化関数（activation）は（sigmoid の一般化である）softmax、損失関数としてcategorical cross-entropy を使うように設定している。また、前述の単純パーセプトロンの例では重み更新の回数（エポック数, nb_epoch）としてデフォルト値である 10 を使用したが、今回の例では精度を出すためにより多くの重み更新が必要のため、nb_epoch を100 に設定している。
# #### ニューラルネットワークで多値分類を行う場合、従属変数を整数ではなくone-hot 表現（ひとつの成分のみが1 であり、残りの成分がすべて0 であるベクトル）として渡すことが多く、keras でもその形を取っている。そのための変換を行う関数がnp_utils.to_categoricalであり、これを使ってy をy_oneHot に変換している。たとえばカテゴリ数が3 でラベルy が2 の場合、そのone-hot 表現y_oneHot は(0,1,0)T になる。
# #### 学習済みのモデルを利用して予測を行うにはたとえば以下のようにする。
# #### model.predict(X[7:8,:])
# #### 配列X を7:8 でスライスしているので、7 行目のみが切り出される。結果として得られる配列はX における7 番目のサンプルがそれぞれのカテゴリに属する確信度を表している。softmax 関数の出力であるので、すべてのカテゴリについて値を足すと1 になる。引数として与えたサンプルはもっとも値の大きいカテゴリに属する可能性が高いと考えられる。

# %%
run pyml/multiLayerPercep.py
# Out:
# /Users/motofumishishikura/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/keras/models.py:848: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
# 150/150 [==============================] - 0s - loss: 1.3426 - acc: 0.2933
# Epoch 2/100
# 150/150 [==============================] - 0s - loss: 1.1466 - acc: 0.2267
# Epoch 3/100
# 150/150 [==============================] - 0s - loss: 1.0484 - acc: 0.2200
# Epoch 4/100
# 150/150 [==============================] - 0s - loss: 0.9950 - acc: 0.3400
# Epoch 5/100
# 150/150 [==============================] - 0s - loss: 0.9503 - acc: 0.6000
# Epoch 6/100
# 150/150 [==============================] - 0s - loss: 0.9096 - acc: 0.5400
# Epoch 7/100
# 150/150 [==============================] - 0s - loss: 0.8756 - acc: 0.6200
# Epoch 8/100
# 150/150 [==============================] - 0s - loss: 0.8407 - acc: 0.6133
# Epoch 9/100
# ...

# %% [markdown]
# ## データセットに入った画像の表示

# %%
"""MNIST"""
from PIL import Image
import numpy as np
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
for i in range(9):
    a = X_train[i,:,:]
    img = Image.fromarray(np.uint8(a))
    img.show()
# Out:
# ...
# 11452416/11490434 [============================>.] - ETA: 0s

# %% [markdown]
# ### MNIST データセットを使った文字認識

# %% [markdown]
# ```python
# '''Trains a simple convnet on the MNIST dataset.
#
# Gets to 99.25% test accuracy after 12 epochs
# (there is still a lot of margin for parameter tuning).
# 16 seconds per epoch on a GRID K520 GPU.
# '''
#
# from __future__ import print_function
# import numpy as np
# np.random.seed(1337)  # for reproducibility
# from keras.datasets import mnist
# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Activation, Flatten
# from keras.layers import Convolution2D, MaxPooling2D
# from keras.utils import np_utils
# import pickle
#
# batch_size = 128
# nb_classes = 10
# nb_epoch = 1
#
# # input image dimensions
# img_rows, img_cols = 28, 28
# # number of convolutional filters to use
# nb_filters = 32
# # size of pooling area for max pooling
# nb_pool = 2
# # convolution kernel size
# nb_conv = 3
#
# # the data, shuffled and split between train and test sets
# (X_train, y_train), (X_test, y_test) = mnist.load_data()
#
# X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
# X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
# X_train = X_train.astype('float32')
# X_test = X_test.astype('float32')
# X_train /= 255
# X_test /= 255
# print('X_train shape:', X_train.shape)
# print(X_train.shape[0], 'train samples')
# print(X_test.shape[0], 'test samples')
#
# # convert class vectors to binary class matrices
# Y_train = np_utils.to_categorical(y_train, nb_classes)
# Y_test = np_utils.to_categorical(y_test, nb_classes)
#
# model = Sequential()
#
# model.add(Convolution2D(nb_filters, nb_conv, nb_conv,
#                         border_mode='valid',
#                         input_shape=(1, img_rows, img_cols)))
# model.add(Activation('relu'))
# model.add(Convolution2D(nb_filters, nb_conv, nb_conv))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(nb_pool, nb_pool)))
# model.add(Dropout(0.25))
#
# model.add(Flatten())
# model.add(Dense(128))
# model.add(Activation('relu'))
# model.add(Dropout(0.5))
# model.add(Dense(nb_classes))
# model.add(Activation('softmax'))
#
# model.compile(loss='categorical_crossentropy',
#               optimizer='adadelta',
#               metrics=['accuracy'])
#
# model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
#           verbose=1, validation_data=(X_test, Y_test))
#
# # save the model and its weights
# model.save_weights('model_weights_mnist_cnn.h5')
# json_string = model.to_json()
# with open('json_model_mnist_cnn.pkl','wb') as f:
#   pickle.dump(json_string, f)
# ```

# %%
run pyml/mnist_cnn_train.py

# %% [markdown]
# ## 相関分析

# %%
cat pyml/corr_happiness.py
# Out:
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# from sklearn import linear_model
# d = pd.read_csv('2017.csv')
# happiness = np.array(d['Happiness.Score'])
# gdp = np.array(d['Economy..GDP.per.Capita.'])
# family = np.array(d['Family'])
# plt.scatter(gdp,happiness)

# %%
run pyml/corr_happiness.py

# %%
cov = np.cov([happiness,gdp,family])
print(cov)
print(np.var(happiness))
# Out:
# [[ 1.27968152  0.38674599  0.24460965]
#  [ 0.38674599  0.1770665   0.08319998]
#  [ 0.24460965  0.08319998  0.08251998]]
# 1.27142550655

# %%
corr= np.corrcoef([happiness,gdp,family])
print(corr)
# Out:
# [[ 1.          0.81246875  0.75273667]
#  [ 0.81246875  1.          0.68829631]
#  [ 0.75273667  0.68829631  1.        ]]

# %%
# corr= np.corrcoef([happiness,gdp,family]
d
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# 5                 Netherlands               6            7.377      7.427426
# 6                      Canada               7            7.316      7.384403
# 7                 New Zealand               8            7.314      7.379510
# 8                      Sweden               9            7.284      7.344095
# 9                   Australia              10            7.284      7.356651
# 10                     Israel              11            7.213      7.279853
# ...

# %% [markdown]
# ## 多変量ガウス分布

# %%
""" 二次元　"""
m = np.array([np.mean(val) for val in [happiness,gdp]]) # 重心を作る，平均ベクトル
cov = np.cov([happiness, gdp]) # 共分散行列
sampleNum = 1000
g = np.random.multivariate_normal(m, cov, sampleNum) # 多変量ガウス分布の作成
plt.scatter(g[:,0],g[:,1],c='blue')
plt.scatter(happiness,gdp,c='red')

# %%
g
# Out:
# (array([[ 14.97278956],
#         [ 14.79933838],
#         [ 15.73755723],
#         ...,
#         [ 14.10686492],
#         [ 13.41085842],
#         [ 13.78215345]]), array([0, 0, 0, ..., 2, 2, 2]))

# %% [markdown]
# ## 混合ガウスモデル -GMM

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
d = pd.read_csv('GlobalTemperatures.csv')
x = d['LandAndOceanAverageTemperature']
z = np.array([value for value in x if not math.isnan(value)])
bins = np.linspace(z.min(), z.max(), 100)
h = plt.hist(z,bins)

# %%
import sklearn.mixture
gmm = sklearn.mixture.GaussianMixture(n_components=3)
gmm.fit(z.reshape((-1,1)))
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#         means_init=None, n_components=3, n_init=1, precisions_init=None,
#         random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
print(gmm.weights_)
print(gmm.means_)
print(gmm.covariances_)
# Out:
# [ 0.24845721  0.36705627  0.38448652]
# [[ 15.32058423]
#  [ 16.58250384]
#  [ 13.83493015]]
# [[[ 0.22436933]]
#
#  [[ 0.1732357 ]]
#
#  [[ 0.21246947]]]

# %%
sampleNum = z.shape[0]
g = gmm.sample(sampleNum)
h = plt.hist(g[0],bins,color='blue',alpha=0.5)
h = plt.hist(z,bins,color='red',alpha=0.5)

# %%
x
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#          ...
# 3162    17.503
# 3163    17.462
# 3164    16.894
# 3165    15.905
# 3166    15.107
# 3167    14.339
# 3168    14.136
# 3169    14.157
# 3170    15.090
# 3171    16.038
# 3172    16.804
# 3173    17.303
# 3174    17.508
# 3175    17.607
# 3176    16.975
# 3177    16.029
# 3178    14.899
# 3179    14.410
# 3180    14.255
# 3181    14.564
# 3182    15.193
# 3183    15.962
# 3184    16.774
# 3185    17.390
# 3186    17.611
# 3187    17.589
# 3188    17.049
# ...

# %% [markdown]
# ## Gaussian Dist. & Randomwalk

# %%
import numpy as np
import matplotlib.pyplot as plt
sampleNum = 10000
timeLength = 100
binNum = 50
loc = np.zeros((sampleNum))
for i in range(sampleNum):
    x = 0
    for t in range(timeLength):
        if np.random.randint(2):
            x += 1
        else:
            x -= 1
        loc[i] = x
stride = np.ceil((loc.max() - loc.min()) / binNum)
bins = np.array(range(np.int(loc.min()), np.int(loc.max()),
np.int(stride)))
h = plt.hist(loc, bins)
